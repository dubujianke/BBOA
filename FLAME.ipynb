# %% [markdown]
# <a href="https://colab.research.google.com/github/dubujianke/BBOA/blob/master/FLAME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 0. Install and Import modules

# %%
# !git clone https://github.com/Rubikplayer/flame-fitting.git
# Out:
# Cloning into 'flame-fitting'...
# remote: Enumerating objects: 186, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 186 (delta 43), reused 34 (delta 34), pack-reused 133
# Receiving objects: 100% (186/186), 10.36 MiB | 21.31 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# !git clone https://gitlab.com/libeigen/eigen.git
# Out:
# Cloning into 'eigen'...
# remote: Enumerating objects: 119070, done.
# remote: Counting objects: 100% (749/749), done.
# remote: Compressing objects: 100% (267/267), done.
# remote: Total 119070 (delta 515), reused 696 (delta 482), pack-reused 118321
# Receiving objects: 100% (119070/119070), 103.32 MiB | 23.69 MiB/s, done.
# Resolving deltas: 100% (98350/98350), done.

# %%
# %cd /content/eigen
# Out:
# /content/eigen

# %%
# %cd /content/flame-fitting
# Out:
# /content/flame-fitting

# %%
# !g++ a.cpp -o hello_eigen

# %%
# !./hello_eigen
# Out:
#   3  -1
# 2.5 1.5
#   3  -1
# 2.5 1.5

# %%
# %cd /content/flame-fitting/sbody/alignment/mesh_distance
# Out:
# /content/flame-fitting/sbody/alignment/mesh_distance

# %%
# !make
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#       |                                                     _m_por
# /usr/local/include/eigen3/Eigen/src/Core/StlIterators.h: In member function ‘Eigen::internal::pointer_based_stl_iterator<XprType>::difference_type Eigen::internal::pointer_based_stl_iterator<XprType>::operator-(const Eigen::internal::pointer_based_stl_iterator<XprType>&) const’:
# /usr/local/include/eigen3/Eigen/src/Core/StlIterators.h:234:13: error: ‘m_ptr’ was not declared in this scope; did you mean ‘_m_por’?
#   234 |     return (m_ptr - other.m_ptr)/m_incr.value();
#       |             ^~~~~
#       |             _m_por
# /usr/local/include/eigen3/Eigen/src/Core/StlIterators.h: In member function ‘Eigen::internal::pointer_based_stl_iterator<XprType>::difference_type Eigen::internal::pointer_based_stl_iterator<XprType>::operator-(const int&) const’:
# ...

# %%
# !pwd
# Out:
# /content/flame-fitting/sbody/alignment/mesh_distance

# %%
# !mkdir build

# %%
# %cd /content/eigen/build
# Out:
# /content/eigen/build

# %%
# !cmake ..

# %%
# !make

# %%
# !make install
# Out:
# Install the project...
# -- Install configuration: "Release"
# -- Installing: /usr/local/include/eigen3/signature_of_eigen3_matrix_library
# -- Installing: /usr/local/share/pkgconfig/eigen3.pc
# -- Installing: /usr/local/include/eigen3/Eigen
# -- Installing: /usr/local/include/eigen3/Eigen/IterativeLinearSolvers
# -- Installing: /usr/local/include/eigen3/Eigen/Eigen
# -- Installing: /usr/local/include/eigen3/Eigen/KLUSupport
# -- Installing: /usr/local/include/eigen3/Eigen/Geometry
# -- Installing: /usr/local/include/eigen3/Eigen/Sparse
# -- Installing: /usr/local/include/eigen3/Eigen/src
# -- Installing: /usr/local/include/eigen3/Eigen/src/IterativeLinearSolvers
# -- Installing: /usr/local/include/eigen3/Eigen/src/IterativeLinearSolvers/BiCGSTAB.h
# -- Installing: /usr/local/include/eigen3/Eigen/src/IterativeLinearSolvers/ConjugateGradient.h
# -- Installing: /usr/local/include/eigen3/Eigen/src/IterativeLinearSolvers/IterativeSolverBase.h
# ...

# %%
# %cd ~
# !pwd
# !mkdir /root/.insightface
# !mkdir /root/.insightface/models
# %cd /root/.insightface/models

# !gdown --id '1-4zbSAb8HkG2t9icReBoF0es9_lymU1s'
# !unzip -d buffalo_l buffalo_l

# https://drive.google.com/file/d/1-7RsaDaps7ogdcX8kmbNHU1HdpT7pdEV/view?usp=share_link
# !gdown --id '1-7RsaDaps7ogdcX8kmbNHU1HdpT7pdEV'
# !unzip -d antelopev2 antelopev2

# %%
# !pip install albumentations>=1.3.0
# !pip install chumpy>=0.70
# !pip install coloredlogs>=15.0.1
# !pip install contourpy>=1.0.6
# !pip install cycler>=0.11.0
# !pip install cython>=0.29.32
# !pip install easydict>=1.10
# !pip install flatbuffers>=22.11.23
# !pip install fonttools>=4.38.0
# !pip install humanfriendly>=10.0
# !pip install imageio>=2.22.4
# !pip install insightface>=0.7
# !pip install joblib>=1.2.0
# !pip install kiwisolver>=1.4.4
# !pip install loguru>=0.6.0
# !pip install matplotlib>=3.6.2
# !pip install mpmath>=1.2.1
# !pip install networkx>=2.8.8
# !pip install onnx>=1.12.0
# !pip install onnxruntime>=1.13.1
# !pip install opencv-python-headless>=4.6.0.66
# !pip install packaging>=21.3
# !pip install prettytable>=3.5.0
# !pip install protobuf>=3.20.1
# !pip install pyparsing>=3.0.9
# !pip install python-dateutil>=2.8.2
# !pip install pywavelets>=1.4.1
# !pip install pyyaml>=6.0
# !pip install qudida>=0.0.4
# !pip install scikit-image>=0.19.3
# !pip install scikit-learn>=1.1.3
# !pip install scipy>=1.9.3
# !pip install sympy>=1.11.1
# !pip install threadpoolctl>=3.1.0
# !pip install tifffile>=2022.10.10
# !pip install tqdm>=4.64.1
# !pip install trimesh>=3.16.4
# !pip install wcwidth>=0.2.5
# !pip install yacs>=0.1.8

# %%
# %cd /content/MICA
# !mkdir data/pretrained/
# %cd /content/MICA/data/pretrained/
# !wget -O mica.tar "https://keeper.mpdl.mpg.de/f/db172dc4bd4f4c0f96de/?dl=1"
# Out:
# /content/MICA
# /content/MICA/data/pretrained
# --2023-04-08 11:42:50--  https://keeper.mpdl.mpg.de/f/db172dc4bd4f4c0f96de/?dl=1
# Resolving keeper.mpdl.mpg.de (keeper.mpdl.mpg.de)... 130.183.207.160
# Connecting to keeper.mpdl.mpg.de (keeper.mpdl.mpg.de)|130.183.207.160|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://keeper.mpdl.mpg.de/seafhttp/files/83494623-7954-4ae6-a3d8-5a06a9d33890/mica.tar [following]
# --2023-04-08 11:42:51--  https://keeper.mpdl.mpg.de/seafhttp/files/83494623-7954-4ae6-a3d8-5a06a9d33890/mica.tar
# Reusing existing connection to keeper.mpdl.mpg.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 502647880 (479M) [application/octet-stream]
# Saving to: ‘mica.tar’
#
# mica.tar            100%[===================>] 479.36M  24.0MB/s    in 21s
#
# 2023-04-08 11:43:12 (22.9 MB/s) - ‘mica.tar’ saved [502647880/502647880]

# %%
# %cd /content/MICA
# !python demo.py
# Out:
# /content/MICA
# 2023-04-08 11:46:15.106 | INFO     | models.flame:__init__:54 - [FLAME] creating the FLAME Decoder
# 2023-04-08 11:46:16.776 | INFO     | models.flame:__init__:54 - [FLAME] creating the FLAME Decoder
# 2023-04-08 11:46:16.942 | INFO     | micalib.models.mica:load_model:52 - [MICA] Trained model found. Path: /content/MICA/data/pretrained/mica.tar | GPU: cuda:0
# /usr/local/lib/python3.9/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:54: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/antelopev2/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...

# %%
# %cd /content/MICA
# !zip -vr demo.zip /content/MICA/demo
# Out:
# /content/MICA
#   adding: content/MICA/demo/	(in=0) (out=0) (stored 0%)
#   adding: content/MICA/demo/input/	(in=0) (out=0) (stored 0%)
#   adding: content/MICA/demo/input/connelly.jpg 	(in=436464) (out=432041) (deflated 1%)
#   adding: content/MICA/demo/input/lawrence.jpg 	(in=510168) (out=508387) (deflated 0%)
#   adding: content/MICA/demo/input/carell.jpg	(in=37532) (out=37028) (deflated 1%)
#   adding: content/MICA/demo/input/justin.png 	(in=1504316) (out=1492397) (deflated 1%)
#   adding: content/MICA/demo/output/	(in=0) (out=0) (stored 0%)
#   adding: content/MICA/demo/output/justin/	(in=0) (out=0) (stored 0%)
#   adding: content/MICA/demo/output/justin/mesh.obj 	(in=359464) (out=153548) (deflated 57%)
#   adding: content/MICA/demo/output/justin/kpt7.npy	(in=212) (out=159) (deflated 25%)
#   adding: content/MICA/demo/output/justin/kpt68.npy	(in=944) (out=888) (deflated 6%)
#   adding: content/MICA/demo/output/justin/mesh.ply 	(in=190181) (out=116711) (deflated 39%)
# ...

# %% [markdown]
# Ensure `torch` and `torchvision` are installed. If `pytorch3d` is not installed, install it using the following cell:

# %%
import os
import sys
import torch
need_pytorch3d=False
try:
    import pytorch3d
except ModuleNotFoundError:
    need_pytorch3d=True
if need_pytorch3d:
    if torch.__version__.startswith("1.13.") and sys.platform.startswith("linux"):
        # We try to install PyTorch3D via a released wheel.
        pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
        version_str="".join([
            f"py3{sys.version_info.minor}_cu",
            torch.version.cuda.replace(".",""),
            f"_pyt{pyt_version_str}"
        ])
        # !pip install fvcore iopath
        # !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
    else:
        # We try to install PyTorch3D from source.
        # !curl -LO https://github.com/NVIDIA/cub/archive/1.10.0.tar.gz
        # !tar xzf 1.10.0.tar.gz    
        os.environ["CUB_HOME"] = os.getcwd() + "/cub-1.10.0"
        # !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'

# %%
# !pip install scikit-image>=0.15  chumpy>=0.69 opencv-python>=4.1.1 PyYAML>=5.1.1 face-alignment

# %%
import os
import torch
import matplotlib.pyplot as plt

# Util function for loading meshes
from pytorch3d.io import load_objs_as_meshes, load_obj

# Data structures and functions for rendering
from pytorch3d.structures import Meshes
from pytorch3d.vis.plotly_vis import AxisArgs, plot_batch_individually, plot_scene
from pytorch3d.vis.texture_vis import texturesuv_image_matplotlib
from pytorch3d.renderer import (
    look_at_view_transform,
    FoVPerspectiveCameras, 
    PointLights, 
    DirectionalLights, 
    Materials, 
    RasterizationSettings, 
    MeshRenderer, 
    MeshRasterizer,  
    SoftPhongShader,
    TexturesUV,
    TexturesVertex
)

# add path for demo utils functions 
import sys
import os
sys.path.append(os.path.abspath(''))

# %% [markdown]
# If using **Google Colab**, fetch the utils file for plotting image grids:

# %% [markdown]
# If running this notebook using **Google Colab**, run the following cell to fetch the mesh obj and texture files and save it at the path `data/cow_mesh`:
# If running locally, the data is already available at the correct path.

# %%
# !mkdir -p data/cow_mesh
# !wget -P data/cow_mesh https://dl.fbaipublicfiles.com/pytorch3d/data/cow_mesh/cow.obj
# !wget -P data/cow_mesh https://dl.fbaipublicfiles.com/pytorch3d/data/cow_mesh/cow.mtl
# !wget -P data/cow_mesh https://dl.fbaipublicfiles.com/pytorch3d/data/cow_mesh/cow_texture.png

# %%
# Setup
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    torch.cuda.set_device(device)
else:
    device = torch.device("cpu")

# Set paths
DATA_DIR = "./data"
obj_filename = os.path.join(DATA_DIR, "cow_mesh/cow.obj")

# Load obj file
mesh = load_objs_as_meshes([obj_filename], device=device)

# %% [markdown]
# #### Let's visualize the texture map
